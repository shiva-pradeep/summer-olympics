# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # 1. In how many cities Summer Olympics is held so far?

# %%
number_of_cities=len(df['City'].unique())
print("number of cities Summer Olympics is held so far is:",number_of_cities)

cities=[]
for i in df['City'].unique():
    cities.append(i)
cities = pd.DataFrame(cities,columns = ['cities'])
cities
# Out:
# number of cities Summer Olympics is held so far is: 22
#                    cities
# 0                  Athens
# 1                   Paris
# 2                St Louis
# 3                  London
# 4               Stockholm
# 5                 Antwerp
# 6               Amsterdam
# 7             Los Angeles
# 8                  Berlin
# 9                Helsinki
# 10  Melbourne / Stockholm
# 11                   Rome
# 12                  Tokyo
# 13                 Mexico
# 14                 Munich
# 15               Montreal
# 16                 Moscow
# 17                  Seoul
# 18              Barcelona
# 19                Atlanta
# 20                 Sydney
# 21                Beijing

# %% [markdown]
# # 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
gold_medals = df[df['Medal'] == 'Gold']
gold_medals['Sport']
no_of_gold_medals=[]
for i in gold_medals['Sport'].unique():
    no_of_gold_medals.append([i,len(df[df['Sport']  == i])])
gold_medals = pd.DataFrame(no_of_gold_medals,columns = ['Sport','No of Gold Medals'])
gold_medals.sort_values(by = 'No of Gold Medals', ascending=False).head()
# Out:
#          Sport  No of Gold Medals
# 0     Aquatics               4170
# 1    Athletics               3638
# 17      Rowing               2667
# 4   Gymnastics               2307
# 3      Fencing               1613

# %%
gold_medals.sort_values(by = 'No of Gold Medals', ascending=False).head().plot(x='Sport' , y='No of Gold Medals', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# # 3. Which sport is having most number of medals so far? (Top 5)

# %%
lf=df
del lf['Year']
del lf['City']
del lf['Discipline']
del lf['Athlete']
del lf['Country']
del lf['Gender']
del lf['Event']

# %%
x = len(lf[lf['Medal'] == 'Gold'])
y = len(lf[lf['Medal'] == 'Silver'])
z = len(lf[lf['Medal'] == 'Bronze'])

# %%
lst=lf.values.tolist()
lst1=[]
for i in lst:
    lst1.append(i[0])
lst2 = list(set(lst1))

count=[]
for i in lst2:
    count.append([i,lst1.count(i)])

count = pd.DataFrame(count,columns = ['Sport','No of Medals'])

# %%
count.sort_values(by = 'No of Medals', ascending=False).head().plot(x='Sport',y='No of Medals', kind = 'bar' , figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %%
df=pd.read_csv("summer.csv")

# %% [markdown]
# # 4. Which player has won most number of medals? (Top 5)#

# %%
lst = df['Athlete'].values.tolist()
lst1=list(set(lst))

cnt = []

for i in lst1:
    cnt.append([i,lst.count(i)])

cnt = pd.DataFrame(cnt,columns = ['Athlete','No of Medals'])

# %%
cnt.sort_values(by = 'No of Medals', ascending = False).head().plot(x = 'Athlete', y = 'No of Medals', kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# # 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
pr_gold_medals = df[df['Medal'] == 'Gold']
pr_gold_medals
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
p_gold_medals=[]
for i in pr_gold_medals['Athlete'].unique():
    p_gold_medals.append([i,len(df[df['Athlete']  == i])])


p_gold_medals = pd.DataFrame(p_gold_medals,columns = ['Player','No of Gold Medals'])
p_gold_medals=p_gold_medals.sort_values(by = 'No of Gold Medals', ascending=False).head()
p_gold_medals
# Out:
#                     Player  No of Gold Medals
# 6851       PHELPS, Michael                 22
# 2714      LATYNINA, Larisa                 18
# 3735    ANDRIANOV, Nikolay                 15
# 2715          ONO, Takashi                 13
# 1963  MANGIAROTTI, Edoardo                 13

# %%
p_gold_medals.sort_values(by = 'No of Gold Medals', ascending=False).head().plot(x='Player',y='No of Gold Medals',kind='bar')
# Out:
# <AxesSubplot:xlabel='Player'>

# %% [markdown]
# # 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df=pd.read_csv("summer.csv")

# %%
fgm= df[df['Country'] == 'IND']
fgm
# Out:
#        Year       City      Sport           Discipline               Athlete  \
# 241    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 244    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 5512   1928  Amsterdam     Hockey               Hockey  ALLEN, Richard James
# 5513   1928  Amsterdam     Hockey               Hockey           CHAND, Dyan
# 5514   1928  Amsterdam     Hockey               Hockey   GATELEY, Maurice A.
# ...     ...        ...        ...                  ...                   ...
# 29879  2012     London     Boxing               Boxing             KOM, Mary
# 30841  2012     London   Shooting             Shooting         NARANG, Gagan
# 30849  2012     London   Shooting             Shooting          KUMAR, Vijay
# 31111  2012     London  Wrestling  Wrestling Freestyle       DUTT, Yogeshwar
# 31118  2012     London  Wrestling  Wrestling Freestyle         KUMAR, Sushil
#
# ...

# %%
fgm[fgm['Medal']=='Gold']
# Out:
#        Year       City     Sport Discipline                       Athlete  \
# 5512   1928  Amsterdam    Hockey     Hockey          ALLEN, Richard James
# 5513   1928  Amsterdam    Hockey     Hockey                   CHAND, Dyan
# 5514   1928  Amsterdam    Hockey     Hockey           GATELEY, Maurice A.
# 5515   1928  Amsterdam    Hockey     Hockey                   GILL, K. S.
# 5516   1928  Amsterdam    Hockey     Hockey  GOODSIR-CULLEN, William John
# ...     ...        ...       ...        ...                           ...
# 16099  1980     Moscow    Hockey     Hockey                  SINGH, Singh
# 16100  1980     Moscow    Hockey     Hockey               SURINDER, Singh
# 16101  1980     Moscow    Hockey     Hockey           SYLVANUS, Dung Dung
# 16102  1980     Moscow    Hockey     Hockey                  ZAFAR, Zafar
# 28856  2008    Beijing  Shooting   Shooting               BINDRA, Abhinav
#
#       Country Gender                     Event Medal
# ...

# %%
print("In the year 1928 India won first Gold Medal in Summer Olympics")
# Out:
# In the year 1928 India won first Gold Medal in Summer Olympics

# %% [markdown]
# # 7. Which event is most popular in terms on number of players? (Top 5)

# %%
tp = df
del tp['Year']
del tp['City']
del tp['Discipline']
del tp['Sport']
del tp['Country']
del tp['Gender']
del tp['Medal']

# %%
x = list(df['Event'].unique())
l1 = df.values.tolist()
x = list(set(x))
l2=[]
for i in l1:
    l2.append(i[1])

most_event=[]
for i in x:
    most_event.append([i,l2.count(i)])

most_event = pd.DataFrame(most_event,columns = ['Event','No of Players'])
most_event
# Out:
#                                       Event  No of Players
# 0                           Épée Individual             93
# 1                       200M Obstacle Event              3
# 2            50+100Y Small Bore Rifle, Team             12
# 3                              Team Pursuit             22
# 4      91 - 99KG, Total (First-Heavyweight)              3
# ..                                      ...            ...
# 661                                    800M            126
# 662              + 87KG (Super Heavyweight)             18
# 663    Double York Round (100Y - 80Y - 60Y)              3
# 664                   K-4 500M (Kayak Four)             84
# 665  100M Running Deer, Single/Double Shots              6
#
# [666 rows x 2 columns]

# %%
most_event.sort_values(by = 'No of Players', ascending = False).head().plot(x = 'Event' , y='No of Players', kind ='bar' , figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Event'>

# %% [markdown]
# # 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df=pd.read_csv("summer.csv")

# %%
female=df[df['Gender']=='Women']
female=female[female['Medal']=='Gold']

# %%
fgm = female['Sport'].values.tolist()
fgm
fgm1 = list(set(fgm))

cnt = []
for i in fgm1:
    cnt.append([i,fgm.count(i)])

cnt = pd.DataFrame(cnt, columns =['Sport', 'No of Female Gold Medalists'])
cnt
# Out:
#                 Sport  No of Female Gold Medalists
# 0             Archery                           39
# 1        Table Tennis                           23
# 2            Football                           86
# 3       Weightlifting                           28
# 4                Golf                            1
# 5          Basketball                          120
# 6          Equestrian                           51
# 7            Handball                          142
# 8           Taekwondo                           16
# 9                Judo                           42
# 10             Tennis                           38
# 11            Skating                            4
# 12  Modern Pentathlon                            4
# 13             Rowing                          217
# 14              Canoe                            9
# 15          Wrestling                           12
# 16            Sailing                           38
# ...

# %%
cnt.sort_values(by = 'No of Female Gold Medalists', ascending = False).head().plot(x='Sport', y='No of Female Gold Medalists', kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Sport'>
